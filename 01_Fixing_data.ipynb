# %% [markdown]
# # PREPARING DATA

# %% [markdown]
# #### Vamos a ver los datos de los diferentes ficheros y prepararlos para que estén disponibles para trabajar con ellos. Cada uno de los datos anuales presentarán características diferentes por lo que su tratamiento será distinto.

# %% [markdown]
# ## Importamos librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Apertura y visualización de los datos

# %% [markdown]
# ### Trabajamos con los datos de 2014

# %%
# Guardando los datos en un dataframe

data_meteo_14 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-meteo-2014.csv',
                            sep=';')
data_pv_14 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-pv-2014.csv',
                         sep=';')

# %%
# Vemos su forma

data_meteo_14.shape
# Out:
# (524863, 9)

# %%
data_pv_14.shape
# Out:
# (262145, 25)

# %%
# Visualizamos un ejemplo de los mismos

data_meteo_14.head()
# Out:
#                     Datetime  Ambient Temperature [ºC]  \
# 0  2014-02-28T04:59:00+00:00                 13.783334
# 1  2014-11-07T06:46:00+00:00                 24.800002
# 2  2014-11-07T06:54:00+00:00                 25.249998
# 3  2014-02-28T05:04:00+00:00                 13.700000
# 4  2014-11-07T07:03:00+00:00                 24.699998
#
#    Global Radiation [W/m2]  Diffuse Radiation [W/m2]  Ultraviolet [W/m2]  \
# 0                 1.417539                  1.672896            0.504882
# 1               193.118980                 43.530248           10.453270
# 2               226.530840                 46.454708           11.877266
# 3                 1.183479                  1.657202            0.505982
# 4               261.758280                 49.932436           13.540898
#
#    Wind Velocity [m/s]  Wind Direction [º]  Precipitation [mm]  \
# 0             2.116667           252.16572                 NaN
# 1             0.400000           159.51002                 NaN
# ...

# %%
data_pv_14.head()
# Out:
#                     Datetime  A_Vertical - Voltage DC [V]  \
# 0  2014-11-15T13:21:00+00:00                         28.7
# 1  2014-11-15T13:23:00+00:00                         28.4
# 2  2014-11-15T13:26:00+00:00                         28.7
# 3  2014-11-15T13:29:00+00:00                         28.8
# 4  2014-11-15T13:32:00+00:00                         28.8
#
#    A_Vertical - Current DC [A]  A_Vertical - Power DC [W]  \
# 0                       6.0100                  172.48700
# 1                       6.0375                  171.46500
# 2                       5.9975                  172.12825
# 3                       5.9300                  170.78400
# 4                       5.8050                  167.18400
#
#    A_Optimal - Voltage DC [V]  A_Optimal - Current DC [A]  \
# 0                       27.85                      7.0300
# 1                       27.85                      7.0200
# 2                       28.05                      6.9925
# ...

# %%
# Vemos el nombre de las columnas para su posterior modificación

data_pv_14.columns
# Out:
# Index(['Datetime', 'A_Vertical - Voltage DC [V]',
#        'A_Vertical - Current DC [A]', 'A_Vertical - Power DC [W]',
#        'A_Optimal - Voltage DC [V]', 'A_Optimal - Current DC [A]',
#        'A_Optimal - Power DC [W]', 'A_Horizontal - Voltage DC [V]',
#        'A_Horizontal - Current DC [A]', 'A_Horizontal - Power DC [W]',
#        'A_Vertical - Temperature [ºC]', 'A_Optimal - Temperature [ºC]',
#        'A_Horizontal - Temperature [ºC]', 'B_Vertical - Voltage DC [V]',
#        'B_Vertical - Current DC [A]', 'B_Vertical - Power DC [W]',
#        'B_Optimal - Voltage DC [V]', 'B_Optimal - Current DC [A]',
#        'B_Optimal - Power DC [W]', 'B_Horizontal - Voltage DC [V]',
#        'B_Horizontal - Current DC [A]', 'B_Horizontal - Power DC [W]',
#        'B_Vertical - Temperature [ºC]', 'B_Optimal - Temperature [ºC]',
#        'B_Horizontal - Temperature [ºC]'],
#       dtype='object')

# %%
# Renombramos las columnas

data_meteo_14 = data_meteo_14.rename(columns={'Ambient Temperature [ºC]':'Ambient_Temperature', 
                                              'Global Radiation [W/m2]':'Global_Radiation',
                                              'Diffuse Radiation [W/m2]':'Diffuse_Radiation', 
                                              'Ultraviolet [W/m2]':'Ultraviolet',
                                              'Wind Velocity [m/s]':'Wind_Velocity',
                                              'Wind Direction [º]':'Wind_direction', 
                                              'Precipitation [mm]':'Precipitation',
                                              'Atmospheric pressure [hPa]':'Atmospheric_pressure'})

# %%
data_pv_14 = data_pv_14.rename(columns={'A_Vertical - Voltage DC [V]':'A_Vertical_VDC',
                                              'A_Vertical - Current DC [A]':'A_Vertical_CDC', 
                                              'A_Vertical - Power DC [W]':'A_Vertical_PDC',
                                              'A_Optimal - Voltage DC [V]':'A_Optimal_VDC', 
                                              'A_Optimal - Current DC [A]':'A_Optimal_CDC',
                                              'A_Optimal - Power DC [W]':'A_Optimal_PDC', 
                                              'A_Horizontal - Voltage DC [V]':'A_Horizontal_VDC',
                                              'A_Horizontal - Current DC [A]':'A_Horizontal_CDC', 
                                              'A_Horizontal - Power DC [W]':'A_Horizontal_PDC',
                                              'A_Vertical - Temperature [ºC]':'A_Vertical_Temperature', 
                                              'A_Optimal - Temperature [ºC]':'A_Optimal_Temperature',
                                              'A_Horizontal - Temperature [ºC]':'A_Horizontal_Temperature', 
                                              'B_Vertical - Voltage DC [V]':'B_Vertical_VDC',
                                              'B_Vertical - Current DC [A]':'B_Vertical_CDC', 
                                              'B_Vertical - Power DC [W]':'B_Vertical_PDC',
                                              'B_Optimal - Voltage DC [V]':'B_Optimal_VDC', 
                                              'B_Optimal - Current DC [A]':'B_Optimal_CDC',
                                              'B_Optimal - Power DC [W]':'B_Optimal_PDC', 
                                              'B_Horizontal - Voltage DC [V]':'B_Horizontal_VDC',
                                              'B_Horizontal - Current DC [A]':'B_Horizontal_CDC', 
                                              'B_Horizontal - Power DC [W]':'B_Horizontal_PDC',
                                              'B_Vertical - Temperature [ºC]':'B_Vertical_Temperature', 
                                              'B_Optimal - Temperature [ºC]':'B_Optimal_Temperature',
                                              'B_Horizontal - Temperature [ºC]':'B_Horizontal_Temperature'})

# %%
# Verificamos los cambios

data_meteo_14.head()
# Out:
#                     Datetime  Ambient_Temperature  Global_Radiation  \
# 0  2014-02-28T04:59:00+00:00            13.783334          1.417539
# 1  2014-11-07T06:46:00+00:00            24.800002        193.118980
# 2  2014-11-07T06:54:00+00:00            25.249998        226.530840
# 3  2014-02-28T05:04:00+00:00            13.700000          1.183479
# 4  2014-11-07T07:03:00+00:00            24.699998        261.758280
#
#    Diffuse_Radiation  Ultraviolet  Wind_Velocity  Wind_direction  \
# 0           1.672896     0.504882       2.116667       252.16572
# 1          43.530248    10.453270       0.400000       159.51002
# 2          46.454708    11.877266       0.600000       110.83258
# 3           1.657202     0.505982       1.150000       211.66448
# 4          49.932436    13.540898       0.466667       107.76016
#
#    Precipitation  Atmospheric_pressure
# 0            NaN                   NaN
# 1            NaN                   NaN
# 2            NaN                   NaN
# ...

# %%
data_pv_14.head()
# Out:
#                     Datetime  A_Vertical_VDC  A_Vertical_CDC  A_Vertical_PDC  \
# 0  2014-11-15T13:21:00+00:00            28.7          6.0100       172.48700
# 1  2014-11-15T13:23:00+00:00            28.4          6.0375       171.46500
# 2  2014-11-15T13:26:00+00:00            28.7          5.9975       172.12825
# 3  2014-11-15T13:29:00+00:00            28.8          5.9300       170.78400
# 4  2014-11-15T13:32:00+00:00            28.8          5.8050       167.18400
#
#    A_Optimal_VDC  A_Optimal_CDC  A_Optimal_PDC  A_Horizontal_VDC  \
# 0          27.85         7.0300     195.785500             29.00
# 1          27.85         7.0200     195.507000             29.00
# 2          28.05         6.9925     196.139625             28.85
# 3          28.15         6.9300     195.079500             29.15
# 4          28.95         6.5525     189.694875             29.15
#
#    A_Horizontal_CDC  A_Horizontal_PDC  ...  B_Vertical_PDC  B_Optimal_VDC  \
# ...

# %%
# Cambiamos el formato de la fecha

data_meteo_14['Datetime'] = pd.to_datetime(data_meteo_14['Datetime'], utc=True)
data_pv_14['Datetime'] = pd.to_datetime(data_pv_14['Datetime'], utc=True)

# %%
# Ordenamos los datos

data_meteo_14 = data_meteo_14.sort_values('Datetime').reset_index(drop=True)
data_pv_14 = data_pv_14.sort_values('Datetime').reset_index(drop=True)

# %%
# Unimos los datos mediante las fechas, para hacer coincidir los datos meteorológicos con los de producción
# ya que estos provienen de archivos diferentes y por tanto con merge los relacionamos por coincidencia de fecha

final_dataset_14 = pd.merge (left = data_meteo_14, right = data_pv_14, left_on = 'Datetime', right_on = 'Datetime')

# %%
# Vemos la forma de la tabla

final_dataset_14.shape
# Out:
# (262131, 33)

# %%
# Reseteamos los indices de la tabla

final_dataset_14.reset_index(drop=True)
# Out:
#                         Datetime  Ambient_Temperature  Global_Radiation  \
# 0      2014-01-01 07:41:00+00:00             9.700000          7.131149
# 1      2014-01-01 07:42:00+00:00             9.700000          7.040442
# 2      2014-01-01 07:43:00+00:00             9.700000          6.594407
# 3      2014-01-01 07:44:00+00:00             9.700000          7.358729
# 4      2014-01-01 07:45:00+00:00             9.700000          7.470711
# ...                          ...                  ...               ...
# 262126 2014-12-31 17:30:00+00:00            12.600000          5.824658
# 262127 2014-12-31 17:31:00+00:00            12.600000          5.625719
# 262128 2014-12-31 17:32:00+00:00            12.533334          5.638842
# 262129 2014-12-31 17:33:00+00:00            12.500000          5.373980
# 262130 2014-12-31 17:34:00+00:00            12.500000          4.707419
#
#         Diffuse_Radiation  Ultraviolet  Wind_Velocity  Wind_direction  \
# ...

# %%
# Eliminamos la columna de precipitación y presión atmosférica. No aportarán información valiosa

final_dataset_14.drop(['Precipitation', 'Atmospheric_pressure'], 
                                         axis='columns', inplace=True)

# %%
# Verificamos los cambios

final_dataset_14.columns
# Out:
# Index(['Datetime', 'Ambient_Temperature', 'Global_Radiation',
#        'Diffuse_Radiation', 'Ultraviolet', 'Wind_Velocity', 'Wind_direction',
#        'A_Vertical_VDC', 'A_Vertical_CDC', 'A_Vertical_PDC', 'A_Optimal_VDC',
#        'A_Optimal_CDC', 'A_Optimal_PDC', 'A_Horizontal_VDC',
#        'A_Horizontal_CDC', 'A_Horizontal_PDC', 'A_Vertical_Temperature',
#        'A_Optimal_Temperature', 'A_Horizontal_Temperature', 'B_Vertical_VDC',
#        'B_Vertical_CDC', 'B_Vertical_PDC', 'B_Optimal_VDC', 'B_Optimal_CDC',
#        'B_Optimal_PDC', 'B_Horizontal_VDC', 'B_Horizontal_CDC',
#        'B_Horizontal_PDC', 'B_Vertical_Temperature', 'B_Optimal_Temperature',
#        'B_Horizontal_Temperature'],
#       dtype='object')

# %%
# Creamos un procedimiento para corregir los valores atipicos y rellenar los NaN

def fill_gap (dataset, columns_to_fill):
    
    # Rellenamos los NaN interpolando entre el valor anterior y posterior.
    
    try:
        dataset = dataset.interpolate(method='linear')
    except:
        dataset = dataset.fillna(method='bfill', limit=1)
    
    for nam_col in list(columns_to_fill):
        
        # Creamos las referencias para identificar los valores atipicos
        
        ref_low = dataset[nam_col].mean() - dataset[nam_col].std() * 3
        ref_high = dataset[nam_col].mean() + dataset[nam_col].std() * 3
        
        # Guardamos los indices de los valores atipicos
        
        indexes = dataset.index[(dataset[nam_col]<ref_low) & (dataset[nam_col]<ref_high)]
        
        # Cambiamos los valores atipicos por valores regulares. Tenemos cuidado con los indices extremos.
        # Si está dentro de los valores intermedios y está considerado outlier, se ejecuta le media entre
        # el anterior y el posterior, en cambio si está en los margenes del archivo, se asigna el valor del
        # más inmediato.
        
        for index in indexes:
                
            if 0 < index < len(dataset):
                dataset.loc[index, nam_col] = (np.mean([dataset.loc[index-1, nam_col], 
                                                        dataset.loc[index+1, nam_col]]))   
            elif index == 0:
                dataset.loc[index, nam_col] = dataset.loc[(index+1), nam_col]
                
            elif index == len(dataset):
                dataset.loc[index, nam_col] = dataset.loc[index-1, nam_col]

    # Si aún queda algún NaN, lo eliminamos.
    
    dataset = dataset.dropna(how='any')
    
    return dataset

# %%
# Aplicamos el procedimiento a los datos del 2014

final_dataset_14 = fill_gap (final_dataset_14, ['Ambient_Temperature', 'Global_Radiation',
       'Diffuse_Radiation', 'Ultraviolet', 'Wind_Velocity',
       'A_Vertical_VDC', 'A_Vertical_CDC', 'A_Vertical_PDC', 'A_Optimal_VDC',
       'A_Optimal_CDC', 'A_Optimal_PDC', 'A_Horizontal_VDC',
       'A_Horizontal_CDC', 'A_Horizontal_PDC', 'A_Vertical_Temperature',
       'A_Optimal_Temperature', 'A_Horizontal_Temperature', 'B_Vertical_VDC',
       'B_Vertical_CDC', 'B_Vertical_PDC', 'B_Optimal_VDC', 'B_Optimal_CDC',
       'B_Optimal_PDC', 'B_Horizontal_VDC', 'B_Horizontal_CDC',
       'B_Horizontal_PDC', 'B_Vertical_Temperature', 'B_Optimal_Temperature',
       'B_Horizontal_Temperature'])

# %%
# Vemos una descripción de los datos

final_dataset_14.describe()
# Out:
#        Ambient_Temperature  Global_Radiation  Diffuse_Radiation  \
# count        246803.000000     246803.000000      246803.000000
# mean             20.237762        460.336598         128.495229
# std               5.047223        313.706412         102.807406
# min               4.300000          0.876493           1.602785
# 25%              16.200000        178.168850          62.582916
# 50%              20.400000        435.300800          98.210056
# 75%              23.949998        727.901640         161.898190
# max              35.399996       1438.887200         776.552080
#
#          Ultraviolet  Wind_Velocity  Wind_direction  A_Vertical_VDC  \
# count  246803.000000  246803.000000   246803.000000   246803.000000
# mean       28.257776       2.644534      207.272491       26.859830
# std        19.387410       1.291603       83.741888        3.740519
# min         0.500673       0.000000        0.000000       14.125000
# ...

# %% [markdown]
# ### Trabajamos con los datos del año 2015

# %% [markdown]
# Repetimos el mismo procedimiento que los valores anteriores.

# %%
data_meteo_15 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-meteo-2015.csv',
                            sep=';')
data_pv_15 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-pv-2015.csv',
                         sep=';')

# %%
data_meteo_15.shape
# Out:
# (437159, 9)

# %%
data_pv_15.shape
# Out:
# (242735, 25)

# %%
data_meteo_15 = data_meteo_15.rename(columns={'Ambient Temperature [ºC]':'Ambient_Temperature', 
                                              'Global Radiation [W/m2]':'Global_Radiation',
                                              'Diffuse Radiation [W/m2]':'Diffuse_Radiation', 
                                              'Ultraviolet [W/m2]':'Ultraviolet',
                                              'Wind Velocity [m/s]':'Wind_Velocity',
                                              'Wind Direction [º]':'Wind_direction', 
                                              'Precipitation [mm]':'Precipitation',
                                              'Atmospheric pressure [hPa]':'Atmospheric_pressure'})

# %%
data_pv_15 = data_pv_15.rename(columns={'A_Vertical - Voltage DC [V]':'A_Vertical_VDC',
                                              'A_Vertical - Current DC [A]':'A_Vertical_CDC', 
                                              'A_Vertical - Power DC [W]':'A_Vertical_PDC',
                                              'A_Optimal - Voltage DC [V]':'A_Optimal_VDC', 
                                              'A_Optimal - Current DC [A]':'A_Optimal_CDC',
                                              'A_Optimal - Power DC [W]':'A_Optimal_PDC', 
                                              'A_Horizontal - Voltage DC [V]':'A_Horizontal_VDC',
                                              'A_Horizontal - Current DC [A]':'A_Horizontal_CDC', 
                                              'A_Horizontal - Power DC [W]':'A_Horizontal_PDC',
                                              'A_Vertical - Temperature [ºC]':'A_Vertical_Temperature', 
                                              'A_Optimal - Temperature [ºC]':'A_Optimal_Temperature',
                                              'A_Horizontal - Temperature [ºC]':'A_Horizontal_Temperature', 
                                              'B_Vertical - Voltage DC [V]':'B_Vertical_VDC',
                                              'B_Vertical - Current DC [A]':'B_Vertical_CDC', 
                                              'B_Vertical - Power DC [W]':'B_Vertical_PDC',
                                              'B_Optimal - Voltage DC [V]':'B_Optimal_VDC', 
                                              'B_Optimal - Current DC [A]':'B_Optimal_CDC',
                                              'B_Optimal - Power DC [W]':'B_Optimal_PDC', 
                                              'B_Horizontal - Voltage DC [V]':'B_Horizontal_VDC',
                                              'B_Horizontal - Current DC [A]':'B_Horizontal_CDC', 
                                              'B_Horizontal - Power DC [W]':'B_Horizontal_PDC',
                                              'B_Vertical - Temperature [ºC]':'B_Vertical_Temperature', 
                                              'B_Optimal - Temperature [ºC]':'B_Optimal_Temperature',
                                              'B_Horizontal - Temperature [ºC]':'B_Horizontal_Temperature'})

# %%
data_meteo_15['Datetime'] = pd.to_datetime(data_meteo_15['Datetime'], utc=True)
data_pv_15['Datetime'] = pd.to_datetime(data_pv_15['Datetime'], utc=True)

# %%
# Ordenamos por fecha

data_meteo_15 = data_meteo_15.sort_values('Datetime').reset_index(drop=True)
data_pv_15 = data_pv_15.sort_values('Datetime').reset_index(drop=True)

# %%
final_dataset_15 = pd.merge (left = data_meteo_15, right = data_pv_15, left_on = 'Datetime', right_on = 'Datetime')

# %%
final_dataset_15.shape
# Out:
# (225510, 33)

# %%
final_dataset_15.drop(['Precipitation', 'Atmospheric_pressure'], axis='columns', inplace=True)

# %%
final_dataset_15 = fill_gap (final_dataset_15, ['Ambient_Temperature', 'Global_Radiation',
       'Diffuse_Radiation', 'Ultraviolet', 'Wind_Velocity',
       'A_Vertical_VDC', 'A_Vertical_CDC', 'A_Vertical_PDC', 'A_Optimal_VDC',
       'A_Optimal_CDC', 'A_Optimal_PDC', 'A_Horizontal_VDC',
       'A_Horizontal_CDC', 'A_Horizontal_PDC', 'A_Vertical_Temperature',
       'A_Optimal_Temperature', 'A_Horizontal_Temperature', 'B_Vertical_VDC',
       'B_Vertical_CDC', 'B_Vertical_PDC', 'B_Optimal_VDC', 'B_Optimal_CDC',
       'B_Optimal_PDC', 'B_Horizontal_VDC', 'B_Horizontal_CDC',
       'B_Horizontal_PDC', 'B_Vertical_Temperature', 'B_Optimal_Temperature',
       'B_Horizontal_Temperature'])

# %%
final_dataset_15.describe()
# Out:
#        Ambient_Temperature  Global_Radiation  Diffuse_Radiation  \
# count        212517.000000     212517.000000      212517.000000
# mean             21.269369        487.107588         134.148671
# std               5.426458        311.940711         102.875597
# min               3.500000          3.361539           2.979969
# 25%              17.383334        200.955120          65.727684
# 50%              21.383334        477.207600         104.268800
# 75%              25.199998        760.285360         165.520200
# max              37.166668       1421.328200         720.352560
#
#          Ultraviolet  Wind_Velocity  Wind_direction  A_Vertical_VDC  \
# count  212517.000000  212517.000000   212517.000000   212517.000000
# mean       29.265542       2.652914      196.677476       26.580888
# std        18.934495       1.287432       83.841613        4.136046
# min         0.592357       0.000000        0.000000       12.800000
# ...

# %% [markdown]
# ### Trabajamos con los datos de 2016

# %% [markdown]
# Repetimos el mismo procedimiento que los valores anteriores.

# %%
data_meteo_16 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-meteo-2016.csv',
                            sep=';')
data_pv_16 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-pv-2016.csv',
                         sep=';')

# %%
data_meteo_16.head()
# Out:
#                     Datetime  Ambient Temperature [ºC]  \
# 0  2016-03-22T07:58:00+00:00                 11.083334
# 1  2016-03-22T08:00:00+00:00                 11.100000
# 2  2016-03-22T08:02:00+00:00                 11.166666
# 3  2016-03-22T08:06:00+00:00                 11.233334
# 4  2016-03-22T08:08:00+00:00                 11.300000
#
#    Global Radiation [W/m2]  Direct Radiation [W/m2]  Ultraviolet [W/m2]  \
# 0                307.19950                144.84512           12.533846
# 1                174.47252                150.80226           10.975560
# 2                360.01548                143.93522           14.223366
# 3                375.56660                128.84222           15.575274
# 4                376.88700                120.42222           15.897234
#
#    Wind Velocity [m/s]  Wind Direction [º]  Precipitation [mm]  \
# 0             3.133333           300.66464                 NaN
# 1             2.900000           294.33660                 NaN
# ...

# %%
data_pv_16.head()
# Out:
#                     Datetime  A_Vertical - Voltage DC [V]  \
# 0  2016-02-11T15:34:00+00:00                        28.50
# 1  2016-06-10T13:23:00+00:00                        29.50
# 2  2016-02-11T10:41:00+00:00                        30.20
# 3  2016-06-10T13:25:00+00:00                        29.50
# 4  2016-02-11T10:44:00+00:00                        29.75
#
#    A_Vertical - Current DC [A]  A_Vertical - Power DC [W]  \
# 0                       1.1275                   32.13375
# 1                       1.7725                   52.28875
# 2                       1.4775                   44.62050
# 3                       1.9775                   58.33625
# 4                       1.4450                   42.98875
#
#    A_Optimal - Voltage DC [V]  A_Optimal - Current DC [A]  \
# 0                       29.40                      1.5725
# 1                       34.20                      0.8050
# 2                       29.25                      2.4250
# ...

# %%
data_meteo_16.shape
# Out:
# (399744, 9)

# %%
data_pv_16.shape
# Out:
# (177772, 25)

# %%
data_meteo_16.columns
# Out:
# Index(['Datetime', 'Ambient Temperature [ºC]', 'Global Radiation [W/m2]',
#        'Direct Radiation [W/m2]', 'Ultraviolet [W/m2]', 'Wind Velocity [m/s]',
#        'Wind Direction [º]', 'Precipitation [mm]',
#        'Atmospheric pressure [hPa]'],
#       dtype='object')

# %%
data_meteo_16 = data_meteo_16.rename(columns={'Ambient Temperature [ºC]':'Ambient_Temperature', 
                                              'Global Radiation [W/m2]':'Global_Radiation',
                                              'Direct Radiation [W/m2]':'Diffuse_Radiation', 
                                              'Ultraviolet [W/m2]':'Ultraviolet',
                                              'Wind Velocity [m/s]':'Wind_Velocity',
                                              'Wind Direction [º]':'Wind_direction', 
                                              'Precipitation [mm]':'Precipitation',
                                              'Atmospheric pressure [hPa]':'Atmospheric_pressure'})

# %%
data_pv_16 = data_pv_16.rename(columns={'A_Vertical - Voltage DC [V]':'A_Vertical_VDC',
                                              'A_Vertical - Current DC [A]':'A_Vertical_CDC', 
                                              'A_Vertical - Power DC [W]':'A_Vertical_PDC',
                                              'A_Optimal - Voltage DC [V]':'A_Optimal_VDC', 
                                              'A_Optimal - Current DC [A]':'A_Optimal_CDC',
                                              'A_Optimal - Power DC [W]':'A_Optimal_PDC', 
                                              'A_Horizontal - Voltage DC [V]':'A_Horizontal_VDC',
                                              'A_Horizontal - Current DC [A]':'A_Horizontal_CDC', 
                                              'A_Horizontal - Power DC [W]':'A_Horizontal_PDC',
                                              'A_Vertical - Temperature [ºC]':'A_Vertical_Temperature', 
                                              'A_Optimal - Temperature [ºC]':'A_Optimal_Temperature',
                                              'A_Horizontal - Temperature [ºC]':'A_Horizontal_Temperature', 
                                              'B_Vertical - Voltage DC [V]':'B_Vertical_VDC',
                                              'B_Vertical - Current DC [A]':'B_Vertical_CDC', 
                                              'B_Vertical - Power DC [W]':'B_Vertical_PDC',
                                              'B_Optimal - Voltage DC [V]':'B_Optimal_VDC', 
                                              'B_Optimal - Current DC [A]':'B_Optimal_CDC',
                                              'B_Optimal - Power DC [W]':'B_Optimal_PDC', 
                                              'B_Horizontal - Voltage DC [V]':'B_Horizontal_VDC',
                                              'B_Horizontal - Current DC [A]':'B_Horizontal_CDC', 
                                              'B_Horizontal - Power DC [W]':'B_Horizontal_PDC',
                                              'B_Vertical - Temperature [ºC]':'B_Vertical_Temperature', 
                                              'B_Optimal - Temperature [ºC]':'B_Optimal_Temperature',
                                              'B_Horizontal - Temperature [ºC]':'B_Horizontal_Temperature'})

# %%
data_meteo_16['Datetime'] = pd.to_datetime(data_meteo_16['Datetime'], utc=True)
data_pv_16['Datetime'] = pd.to_datetime(data_pv_16['Datetime'], utc=True)

# %%
# Ordenamos por fechas

data_meteo_16 = data_meteo_16.sort_values('Datetime').reset_index(drop=True)
data_pv_16 = data_pv_16.sort_values('Datetime').reset_index(drop=True)

# %%
final_dataset_16 = pd.merge (left = data_meteo_16, right = data_pv_16, left_on = 'Datetime', right_on = 'Datetime')

# %%
final_dataset_16.shape
# Out:
# (139080, 33)

# %%
final_dataset_16.drop(['Precipitation', 'Atmospheric_pressure'], axis='columns', inplace=True)

# %%
final_dataset_16 = fill_gap (final_dataset_16, ['Ambient_Temperature', 'Global_Radiation',
       'Diffuse_Radiation', 'Ultraviolet', 'Wind_Velocity',
       'A_Vertical_VDC', 'A_Vertical_CDC', 'A_Vertical_PDC', 'A_Optimal_VDC',
       'A_Optimal_CDC', 'A_Optimal_PDC', 'A_Horizontal_VDC',
       'A_Horizontal_CDC', 'A_Horizontal_PDC', 'A_Vertical_Temperature',
       'A_Optimal_Temperature', 'A_Horizontal_Temperature', 'B_Vertical_VDC',
       'B_Vertical_CDC', 'B_Vertical_PDC', 'B_Optimal_VDC', 'B_Optimal_CDC',
       'B_Optimal_PDC', 'B_Horizontal_VDC', 'B_Horizontal_CDC',
       'B_Horizontal_PDC', 'B_Vertical_Temperature', 'B_Optimal_Temperature',
       'B_Horizontal_Temperature'])

# %%
final_dataset_16.describe()
# Out:
#        Ambient_Temperature  Global_Radiation  Diffuse_Radiation  \
# count        131260.000000     131260.000000      131260.000000
# mean             22.085024        460.908646         118.730844
# std               6.369448        308.973982          87.468032
# min               4.700001          1.917793           1.745721
# 25%              16.500000        182.771405          60.834308
# 50%              22.733332        432.580180          93.195560
# 75%              27.633334        720.156500         150.511940
# max              38.300000       1413.023400         714.390160
#
#          Ultraviolet  Wind_Velocity  Wind_direction  A_Vertical_VDC  \
# count  131260.000000  131260.000000   131260.000000   131260.000000
# mean       27.913256       2.677501      190.873862       26.375847
# std        19.231978       1.333220       89.519529        4.302602
# min         0.731041       0.000000        0.000000       12.450000
# ...

# %% [markdown]
# ### Trabajamos con los datos de 2017

# %% [markdown]
# Repetimos el mismo procedimiento que los valores anteriores.

# %%
data_meteo_17 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-meteo-2017.csv',
                            sep=';')
data_pv_17 = pd.read_csv('/home/dsc/Documents/TFM-Sun-Power-Prediction/dataset/sunlab-faro-pv-2017.csv',
                         sep=';')

# %%
data_meteo_17.head()
# Out:
#                     Datetime  Ambient Temperature [ºC]  \
# 0  2017-06-13T04:11:00+02:00                      21.4
# 1  2017-06-13T04:12:00+02:00                      21.4
# 2  2017-06-13T04:16:00+02:00                      21.5
# 3  2017-06-13T04:34:00+02:00                      21.6
# 4  2017-06-23T23:29:00+02:00                      29.0
#
#    Global Radiation [W/m2]  Diffuse Radiation [W/m2]  Ultraviolet [W/m2]  \
# 0                 1.135318                  1.688030            0.508061
# 1                 1.202852                  1.693716            0.508069
# 2                 1.311066                  1.710920            0.509157
# 3                 1.530087                  1.683353            0.503610
# 4                 1.901296                  2.147049            0.508236
#
#    Wind Velocity [m/s]  Wind Direction [º]  Precipitation [mm]  \
# 0             4.150000           105.84458                 0.0
# 1             2.850000           104.66702                 0.0
# ...

# %%
data_pv_17.head()
# Out:
#                     Datetime  A_Vertical - Voltage DC [V]  \
# 0  2017-04-12T17:28:00+00:00                        27.00
# 1  2017-04-12T17:34:00+00:00                        26.65
# 2  2017-04-12T17:43:00+00:00                        26.95
# 3  2017-04-12T17:47:00+00:00                        27.05
# 4  2017-04-12T17:57:00+00:00                        26.95
#
#    A_Vertical - Current DC [A]  A_Vertical - Power DC [W]  \
# 0                       0.8050                  21.735000
# 1                       0.7450                  19.854250
# 2                       0.6575                  17.719625
# 3                       0.6200                  16.771000
# 4                       0.5200                  14.014000
#
#    A_Optimal - Voltage DC [V]  A_Optimal - Current DC [A]  \
# 0                       28.35                      1.6850
# 1                       27.90                      1.5150
# 2                       27.55                      1.2425
# ...

# %%
data_meteo_17['Datetime'] = pd.to_datetime(data_meteo_17['Datetime'], utc=True)
data_pv_17['Datetime'] = pd.to_datetime(data_pv_17['Datetime'], utc=True)

# %%
data_meteo_17 = data_meteo_17.rename(columns={'Ambient Temperature [ºC]':'Ambient_Temperature', 
                                              'Global Radiation [W/m2]':'Global_Radiation',
                                              'Diffuse Radiation [W/m2]':'Diffuse_Radiation', 
                                              'Ultraviolet [W/m2]':'Ultraviolet',
                                              'Wind Velocity [m/s]':'Wind_Velocity',
                                              'Wind Direction [º]':'Wind_direction', 
                                              'Precipitation [mm]':'Precipitation',
                                              'Atmospheric pressure [hPa]':'Atmospheric_pressure'})

# %%
data_pv_17 = data_pv_17.rename(columns={'A_Vertical - Voltage DC [V]':'A_Vertical_VDC',
                                              'A_Vertical - Current DC [A]':'A_Vertical_CDC', 
                                              'A_Vertical - Power DC [W]':'A_Vertical_PDC',
                                              'A_Optimal - Voltage DC [V]':'A_Optimal_VDC', 
                                              'A_Optimal - Current DC [A]':'A_Optimal_CDC',
                                              'A_Optimal - Power DC [W]':'A_Optimal_PDC', 
                                              'A_Horizontal - Voltage DC [V]':'A_Horizontal_VDC',
                                              'A_Horizontal - Current DC [A]':'A_Horizontal_CDC', 
                                              'A_Horizontal - Power DC [W]':'A_Horizontal_PDC',
                                              'A_Vertical - Temperature [ºC]':'A_Vertical_Temperature', 
                                              'A_Optimal - Temperature [ºC]':'A_Optimal_Temperature',
                                              'A_Horizontal - Temperature [ºC]':'A_Horizontal_Temperature', 
                                              'B_Vertical - Voltage DC [V]':'B_Vertical_VDC',
                                              'B_Vertical - Current DC [A]':'B_Vertical_CDC', 
                                              'B_Vertical - Power DC [W]':'B_Vertical_PDC',
                                              'B_Optimal - Voltage DC [V]':'B_Optimal_VDC', 
                                              'B_Optimal - Current DC [A]':'B_Optimal_CDC',
                                              'B_Optimal - Power DC [W]':'B_Optimal_PDC', 
                                              'B_Horizontal - Voltage DC [V]':'B_Horizontal_VDC',
                                              'B_Horizontal - Current DC [A]':'B_Horizontal_CDC', 
                                              'B_Horizontal - Power DC [W]':'B_Horizontal_PDC',
                                              'B_Vertical - Temperature [ºC]':'B_Vertical_Temperature', 
                                              'B_Optimal - Temperature [ºC]':'B_Optimal_Temperature',
                                              'B_Horizontal - Temperature [ºC]':'B_Horizontal_Temperature'})

# %%
data_meteo_17.head()
# Out:
#                    Datetime  Ambient_Temperature  Global_Radiation  \
# 0 2017-06-13 02:11:00+00:00                 21.4          1.135318
# 1 2017-06-13 02:12:00+00:00                 21.4          1.202852
# 2 2017-06-13 02:16:00+00:00                 21.5          1.311066
# 3 2017-06-13 02:34:00+00:00                 21.6          1.530087
# 4 2017-06-23 21:29:00+00:00                 29.0          1.901296
#
#    Diffuse_Radiation  Ultraviolet  Wind_Velocity  Wind_direction  \
# 0           1.688030     0.508061       4.150000       105.84458
# 1           1.693716     0.508069       2.850000       104.66702
# 2           1.710920     0.509157       3.683334       103.33748
# 3           1.683353     0.503610       3.433334       113.17200
# 4           2.147049     0.508236       0.566667       247.80524
#
#    Precipitation  Atmospheric_pressure
# 0            0.0             1007.0334
# 1            0.0             1007.0334
# 2            0.0             1007.0668
# ...

# %%
data_pv_17.head()
# Out:
#                    Datetime  A_Vertical_VDC  A_Vertical_CDC  A_Vertical_PDC  \
# 0 2017-04-12 17:28:00+00:00           27.00          0.8050       21.735000
# 1 2017-04-12 17:34:00+00:00           26.65          0.7450       19.854250
# 2 2017-04-12 17:43:00+00:00           26.95          0.6575       17.719625
# 3 2017-04-12 17:47:00+00:00           27.05          0.6200       16.771000
# 4 2017-04-12 17:57:00+00:00           26.95          0.5200       14.014000
#
#    A_Optimal_VDC  A_Optimal_CDC  A_Optimal_PDC  A_Horizontal_VDC  \
# 0          28.35         1.6850      47.769750             28.05
# 1          27.90         1.5150      42.268500             27.75
# 2          27.55         1.2425      34.230875             27.60
# 3          27.55         1.1150      30.718250             27.65
# 4          27.40         0.8200      22.468000             28.75
#
#    A_Horizontal_CDC  A_Horizontal_PDC  ...  B_Vertical_PDC  B_Optimal_VDC  \
# ...

# %%
final_dataset_17 = pd.merge (left = data_meteo_17, right = data_pv_17, left_on = 'Datetime', right_on = 'Datetime')

# %%
# Ordenamos por fecha

data_meteo_17 = data_meteo_17.sort_values('Datetime').reset_index(drop=True)
data_pv_17 = data_pv_17.sort_values('Datetime').reset_index(drop=True)

# %%
final_dataset_17.shape
# Out:
# (206957, 33)

# %%
final_dataset_17.drop(['Precipitation', 'Atmospheric_pressure'], axis='columns', inplace=True)

# %%
final_dataset_17.shape
# Out:
# (206957, 31)

# %%
final_dataset_17 = fill_gap (final_dataset_17, ['Ambient_Temperature', 'Global_Radiation',
       'Diffuse_Radiation', 'Ultraviolet', 'Wind_Velocity',
       'A_Vertical_VDC', 'A_Vertical_CDC', 'A_Vertical_PDC', 'A_Optimal_VDC',
       'A_Optimal_CDC', 'A_Optimal_PDC', 'A_Horizontal_VDC',
       'A_Horizontal_CDC', 'A_Horizontal_PDC', 'A_Vertical_Temperature',
       'A_Optimal_Temperature', 'A_Horizontal_Temperature', 'B_Vertical_VDC',
       'B_Vertical_CDC', 'B_Vertical_PDC', 'B_Optimal_VDC', 'B_Optimal_CDC',
       'B_Optimal_PDC', 'B_Horizontal_VDC', 'B_Horizontal_CDC',
       'B_Horizontal_PDC', 'B_Vertical_Temperature', 'B_Optimal_Temperature',
       'B_Horizontal_Temperature'])

# %%
final_dataset_17.shape
# Out:
# (203097, 31)

# %%
final_dataset_17.describe()
# Out:
#        Ambient_Temperature  Global_Radiation  Diffuse_Radiation  \
# count        203097.000000     203097.000000      203097.000000
# mean             21.399671        462.741953         129.134046
# std               5.586697        323.184808         104.771711
# min               3.000000          0.732156           1.626869
# 25%              17.000000        167.679020          60.578404
# 50%              21.433334        447.357880          99.255776
# 75%              25.933334        731.379680         174.083680
# max              37.899996       1484.379800         715.146720
#
#          Ultraviolet  Wind_Velocity  Wind_direction  A_Vertical_VDC  \
# count  203097.000000  203097.000000   203097.000000   203097.000000
# mean       27.797956       2.651215      191.044225       26.305041
# std        19.711869       1.261512       86.131858        4.500542
# min         0.501036       0.000000        0.000000       12.450000
# ...

# %% [markdown]
# ### Concatenamos todos los dataset y dividimos entre entrenamiento y test.

# %% [markdown]
# Para poder entrenar y determinar si el modelo es valido y adecuado, haremos una separación del 20% de los datos para testear y del 80% para entrenar.

# %%
final_dataset = pd.concat([final_dataset_14, final_dataset_15, 
                                 final_dataset_16, final_dataset_17], axis = 0).reset_index(drop = True)

# %%
from sklearn.model_selection import train_test_split

final_train_dataset, final_test_dataset = train_test_split(final_dataset, test_size = 0.20)

# %%
# Desordenamos el DataFrame de entrenamiento para asegurarnos de que no existe estacionalidad en los datos

from sklearn.utils import shuffle

final_train_dataset = shuffle(final_train_dataset)

# %% [markdown]
# ### Guardamos los dataset en archivos para su posterior uso

# %%
final_train_dataset.to_csv('train_dataset.csv', sep=';', index=False)
final_test_dataset.to_csv('test_dataset.csv', sep=';', index=False)
